# %% [markdown]
# <a href="https://colab.research.google.com/github/khb6/video-processing/blob/main/ch06_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
import cv2
from google.colab.patches import cv2_imshow
import numpy as np
import matplotlib.pyplot as plt

# %%
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import cv2
import matplotlib.pyplot as plt

img = cv2.imread('/content/gdrive/My Drive/pj1/영상이미지/Images/lena.jpg')
RGB_Img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

gImg = cv2.cvtColor(RGB_Img, cv2.COLOR_BGR2GRAY)
print(gImg.shape)
plt.imshow(gImg, cmap='gray')  # cmap 파라미터를 'gray'로 설정
plt.axis('off')  # 축 숨기기 (선택 사항)
plt.show()
# Out:
# (512, 512)

# %%
gy = np.array([[-1, -2, -1],[0, 0, 0], [1, 2, 1]], dtype = int)
gx = np.array([[-1, 0, 1],[-2, 0, -2], [-1,0,1]], dtype = int)

# %%
x = cv2.filter2D(gImg, -1, gx)
y = cv2.filter2D(gImg, -1, gy)

# %%
absX = cv2.convertScaleAbs(x)
absY = cv2.convertScaleAbs(y)
outImg = cv2.addWeighted(absX, 0.5, absY, 0.5, 0)

# %%
gBin = np.zeros((gImg.shape[0], gImg.shape[1]), dtype = np.ubyte)

# %%
threshold = 30

for h in range(gImg.shape[0]):
  for w in range(gImg.shape[1]):
    if(outImg[h,w] > threshold):
      gBin[h,w] = 255

cv2_imshow(outImg)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
cannnyImg=cv2.Canny(gImg, 200, 250)
cv_2  imshow(cannyImg)
